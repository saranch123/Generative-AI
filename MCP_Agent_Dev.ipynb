# %%
# !pip install -q streamlit yfinance pandas
# !npm -g install localtunnel
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 23.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 53.1 MB/s eta 0:00:00
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴
# added 22 packages in 3s
# ⠴
# ⠴3 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴

# %%
# %%writefile app.py
import streamlit as st
import yfinance as yf
import pandas as pd

st.set_page_config(page_title="Global Finance Agent", page_icon="💰", layout="centered")
st.title("💰 Global Finance Agent")
st.write("Select a country to view its **currency**, **exchange rates**, **major index**, and **HQ location (map)**.")

# Country config (manual mapping for reliability)
country_data = {
    "Japan": {
        "currency": "JPY",
        "ticker": "^N225",  # Nikkei 225
        "exchange_name": "Tokyo Stock Exchange",
        "coords": [35.6812, 139.7745],
    },
    "India": {
        "currency": "INR",
        "ticker": "^BSESN",  # Sensex
        "exchange_name": "Bombay Stock Exchange (BSE)",
        "coords": [18.9291, 72.8339],
    },
    "USA": {
        "currency": "USD",
        "ticker": "^GSPC",  # S&P 500
        "exchange_name": "New York Stock Exchange (NYSE)",
        "coords": [40.7069, -74.0113],
    },
    "UK": {
        "currency": "GBP",
        "ticker": "^FTSE",  # FTSE 100
        "exchange_name": "London Stock Exchange",
        "coords": [51.5150, -0.0982],
    },
}

# Sidebar selection
selected_country = st.sidebar.selectbox("Choose a Country", list(country_data.keys()))
data = country_data[selected_country]

st.header(f"📌 Analysis for {selected_country}")

# --- Currency + Exchange Rates ---
st.subheader(f"💱 Official Currency: {data['currency']}")
col1, col2, col3, col4 = st.columns(4)

def get_rate(from_curr, to_curr):
    if from_curr == to_curr:
        return 1.0
    pair = f"{from_curr}{to_curr}=X"
    try:
        df = yf.Ticker(pair).history(period="5d")
        return float(df["Close"].dropna().iloc[-1])
    except Exception:
        return None

usd = get_rate(data["currency"], "USD")
inr = get_rate(data["currency"], "INR")
gbp = get_rate(data["currency"], "GBP")
eur = get_rate(data["currency"], "EUR")

col1.metric("To USD ($)", f"{usd:.4f}" if usd else "N/A")
col2.metric("To INR (₹)", f"{inr:.4f}" if inr else "N/A")
col3.metric("To GBP (£)", f"{gbp:.4f}" if gbp else "N/A")
col4.metric("To EUR (€)", f"{eur:.4f}" if eur else "N/A")

# --- Stock Index ---
st.subheader(f"📈 Major Index: {data['ticker']}")
try:
    stock = yf.Ticker(data["ticker"])
    hist = stock.history(period="1mo")

    if hist.empty:
        st.warning("No mar
# Out:
# Writing app.py

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴
# ...
#
# ⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇your url is: https://wild-turtles-cheer.loca.lt
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.50.175.0:8501
